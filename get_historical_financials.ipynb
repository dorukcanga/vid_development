# %%
# !pip install -r requirements.txt
# Out:
# Collecting scipy (from -r requirements.txt (line 1))
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x1129b4050>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /packages/f2/1e/41e1a295dc54d21f6a6b2ff5e85e398b5aea076cf69fdedbc943b9c73b2d/scipy-1.14.0-cp312-cp312-macosx_14_0_x86_64.whl.metadata
# ^C

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.23.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from plotly) (24.1)
# Downloading plotly-5.23.0-py3-none-any.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.23.0 tenacity-9.0.0

# %%
# !pip install tensorflow torch xgboost lightgbm catboost
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.16.2-cp312-cp312-macosx_10_15_x86_64.whl.metadata (4.1 kB)
# Collecting torch
#   Downloading torch-2.2.2-cp312-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting xgboost
#   Downloading xgboost-2.1.1-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl.metadata (2.1 kB)
# Collecting lightgbm
#   Using cached lightgbm-4.5.0-py3-none-macosx_10_15_x86_64.whl.metadata (17 kB)
# Collecting catboost
#   Downloading catboost-1.2.5-cp312-cp312-macosx_11_0_universal2.whl.metadata (1.2 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow)
#   Downloading h5py-3.11.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-macosx_10_9_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow)
#   Downloading ml_dtypes-0.3.2-cp312-cp312-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from tensorflow) (24.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-4.25.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.16.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.65.4-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.3 kB)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow)
#   Downloading keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from tensorflow)
#   Downloading numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl.metadata (61 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting sympy (from torch)
#   Downloading sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from torch) (3.1.4)
# Collecting fsspec (from torch)
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from xgboost) (1.14.0)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from catboost) (3.9.1.post1)
# Requirement already satisfied: pandas>=0.24 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from catboost) (2.2.2)
# Requirement already satisfied: plotly in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from catboost) (5.23.0)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.0.0->tensorflow)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.0.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow)
#   Downloading optree-0.12.1-cp312-cp312-macosx_10_9_universal2.whl.metadata (47 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Collecting markdown>=2.6.8 (from tensorboard<2.17,>=2.16->tensorflow)
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.17,>=2.16->tensorflow)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from plotly->catboost) (9.0.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.0.0->tensorflow)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.16.2-cp312-cp312-macosx_10_15_x86_64.whl (259.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.7/259.7 MB 2.3 MB/s eta 0:00:0000:0100:03
# Downloading torch-2.2.2-cp312-none-macosx_10_9_x86_64.whl (150.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 MB 2.7 MB/s eta 0:00:0000:0100:02
# Downloading xgboost-2.1.1-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.5 MB/s eta 0:00:0000:0100:01
# Using cached lightgbm-4.5.0-py3-none-macosx_10_15_x86_64.whl (1.9 MB)
# Downloading catboost-1.2.5-cp312-cp312-macosx_11_0_universal2.whl (26.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 3.1 MB/s eta 0:00:0000:0100:01
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.65.4-cp312-cp312-macosx_10_9_universal2.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading h5py-3.11.0-cp312-cp312-macosx_10_9_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading keras-3.4.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading libclang-18.1.1-py2.py3-none-macosx_10_9_x86_64.whl (26.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 3.0 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.3.2-cp312-cp312-macosx_10_9_universal2.whl (393 kB)
# Downloading numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 2.0 MB/s eta 0:00:0000:0100:01
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading protobuf-4.25.4-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading wrapt-1.16.0-cp312-cp312-macosx_10_9_x86_64.whl (37 kB)
# Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading sympy-1.13.2-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 2.0 MB/s eta 0:00:0000:01
# Downloading tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Downloading wheel-0.44.0-py3-none-any.whl (67 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp312-cp312-macosx_10_9_universal2.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 950.5 kB/s eta 0:00:00:--:--
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, mpmath, libclang, flatbuffers, wrapt, wheel, werkzeug, typing-extensions, termcolor, tensorboard-data-server, sympy, protobuf, numpy, networkx, mdurl, markdown, grpcio, graphviz, google-pasta, gast, fsspec, filelock, absl-py, torch, tensorboard, optree, opt-einsum, ml-dtypes, markdown-it-py, h5py, astunparse, xgboost, rich, lightgbm, keras, catboost, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 catboost-1.2.5 filelock-3.15.4 flatbuffers-24.3.25 fsspec-2024.6.1 gast-0.6.0 google-pasta-0.2.0 graphviz-0.20.3 grpcio-1.65.4 h5py-3.11.0 keras-3.4.1 libclang-18.1.1 lightgbm-4.5.0 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 mpmath-1.3.0 namex-0.0.8 networkx-3.3 numpy-1.26.4 opt-einsum-3.3.0 optree-0.12.1 protobuf-4.25.4 rich-13.7.1 sympy-1.13.2 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.2 termcolor-2.4.0 torch-2.2.2 typing-extensions-4.12.2 werkzeug-3.0.3 wheel-0.44.0 wrapt-1.16.0 xgboost-2.1.1

# %%
# !pip install keras torchvision statsmodels tqdm joblib nltk gensim
# Out:
# Requirement already satisfied: keras in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (3.4.1)
# Collecting torchvision
#   Downloading torchvision-0.17.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Collecting statsmodels
#   Downloading statsmodels-0.14.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (9.2 kB)
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: joblib in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (1.4.2)
# Collecting nltk
#   Downloading nltk-3.8.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting gensim
#   Downloading gensim-4.3.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from keras) (0.3.2)
# Requirement already satisfied: packaging in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from keras) (24.1)
# Requirement already satisfied: torch==2.2.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from torchvision) (2.2.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: filelock in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from torch==2.2.2->torchvision) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from torch==2.2.2->torchvision) (4.12.2)
# Requirement already satisfied: sympy in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from torch==2.2.2->torchvision) (1.13.2)
# Requirement already satisfied: networkx in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from torch==2.2.2->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from torch==2.2.2->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from torch==2.2.2->torchvision) (2024.6.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from statsmodels) (1.14.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting click (from nltk)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.7.24-cp312-cp312-macosx_10_9_x86_64.whl.metadata (40 kB)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels)
#   Downloading scipy-1.13.1-cp312-cp312-macosx_10_9_x86_64.whl.metadata (60 kB)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-7.0.4-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Requirement already satisfied: wrapt in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from jinja2->torch==2.2.2->torchvision) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from sympy->torch==2.2.2->torchvision) (1.3.0)
# Downloading torchvision-0.17.2-cp312-cp312-macosx_10_13_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading statsmodels-0.14.2-cp312-cp312-macosx_10_9_x86_64.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Downloading nltk-3.8.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading gensim-4.3.3-cp312-cp312-macosx_10_9_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading regex-2024.7.24-cp312-cp312-macosx_10_9_x86_64.whl (282 kB)
# Downloading scipy-1.13.1-cp312-cp312-macosx_10_9_x86_64.whl (39.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 1.3 MB/s eta 0:00:0000:0100:02
# Downloading smart_open-7.0.4-py3-none-any.whl (61 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Installing collected packages: tqdm, smart-open, scipy, regex, patsy, click, nltk, gensim, torchvision, statsmodels
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.0
#     Uninstalling scipy-1.14.0:
#       Successfully uninstalled scipy-1.14.0
# Successfully installed click-8.1.7 gensim-4.3.3 nltk-3.8.2 patsy-0.5.6 regex-2024.7.24 scipy-1.13.1 smart-open-7.0.4 statsmodels-0.14.2 torchvision-0.17.2 tqdm-4.66.5

# %%
# !pip install pillow imageio scikit-image networkx streamlit docker
# Out:
# Requirement already satisfied: pillow in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (10.4.0)
# Collecting imageio
#   Downloading imageio-2.34.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting scikit-image
#   Downloading scikit_image-0.24.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: networkx in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (3.3)
# Collecting streamlit
#   Downloading streamlit-1.37.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting docker
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from imageio) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from scikit-image) (1.13.1)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2024.8.10-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from scikit-image) (24.1)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.4.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.4.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from streamlit) (4.25.4)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-17.0.0-cp312-cp312-macosx_10_15_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: requests<3,>=2.27 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from streamlit) (13.7.1)
# Collecting tenacity<9,>=8.1.0 (from streamlit)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from docker) (2.2.2)
# Requirement already satisfied: jinja2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Collecting narwhals>=1.1.0 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.3.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Downloading imageio-2.34.2-py3-none-any.whl (313 kB)
# Downloading scikit_image-0.24.0-cp312-cp312-macosx_10_9_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading streamlit-1.37.1-py2.py3-none-any.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading altair-5.4.0-py3-none-any.whl (671 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.7/671.7 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading cachetools-5.4.0-py3-none-any.whl (9.5 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading pyarrow-17.0.0-cp312-cp312-macosx_10_15_x86_64.whl (29.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 1.4 MB/s eta 0:00:0000:0100:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tifffile-2024.8.10-py3-none-any.whl (225 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading narwhals-1.3.0-py3-none-any.whl (138 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: toml, tifffile, tenacity, smmap, pyarrow, narwhals, lazy-loader, imageio, cachetools, blinker, scikit-image, pydeck, gitdb, docker, gitpython, altair, streamlit
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed altair-5.4.0 blinker-1.8.2 cachetools-5.4.0 docker-7.1.0 gitdb-4.0.11 gitpython-3.1.43 imageio-2.34.2 lazy-loader-0.4 narwhals-1.3.0 pyarrow-17.0.0 pydeck-0.9.1 scikit-image-0.24.0 smmap-5.0.1 streamlit-1.37.1 tenacity-8.5.0 tifffile-2024.8.10 toml-0.10.2

# %%
# !pip install requests django flask beautifulsoup4 fastapi
# Out:
# Requirement already satisfied: requests in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (2.32.3)
# Collecting django
#   Downloading Django-5.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting flask
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: beautifulsoup4 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (4.12.3)
# Collecting fastapi
#   Downloading fastapi-0.112.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests) (2024.7.4)
# Collecting asgiref<4,>=3.8.1 (from django)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting sqlparse>=0.3.1 (from django)
#   Downloading sqlparse-0.5.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from flask) (3.1.4)
# Collecting itsdangerous>=2.1.2 (from flask)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: click>=8.1.3 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from flask) (1.8.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from beautifulsoup4) (2.5)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi)
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask) (2.1.5)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Downloading pydantic_core-2.20.1-cp312-cp312-macosx_10_12_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from starlette<0.38.0,>=0.37.2->fastapi) (4.4.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi) (1.3.1)
# Downloading Django-5.1-py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading fastapi-0.112.0-py3-none-any.whl (93 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Downloading pydantic_core-2.20.1-cp312-cp312-macosx_10_12_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading sqlparse-0.5.1-py3-none-any.whl (44 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Installing collected packages: sqlparse, pydantic-core, itsdangerous, asgiref, annotated-types, starlette, pydantic, flask, django, fastapi
# Successfully installed annotated-types-0.7.0 asgiref-3.8.1 django-5.1 fastapi-0.112.0 flask-3.0.3 itsdangerous-2.2.0 pydantic-2.8.2 pydantic-core-2.20.1 sqlparse-0.5.1 starlette-0.37.2

# %%
# !pip install imbalanced-learn autofeatselect dash category_encoders yfinance
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting autofeatselect
#   Downloading AutoFeatSelect-0.1.5-py3-none-any.whl.metadata (5.8 kB)
# Collecting dash
#   Downloading dash-2.17.1-py3-none-any.whl.metadata (10 kB)
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting yfinance
#   Downloading yfinance-0.2.41-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17.3 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from imbalanced-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from imbalanced-learn) (3.5.0)
# Requirement already satisfied: xgboost in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from autofeatselect) (2.1.1)
# Requirement already satisfied: lightgbm in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from autofeatselect) (4.5.0)
# Collecting Boruta (from autofeatselect)
#   Downloading Boruta-0.3-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from dash) (3.0.3)
# Requirement already satisfied: plotly>=5.0.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from dash) (5.23.0)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash)
#   Downloading importlib_metadata-8.2.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from dash) (72.1.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from category_encoders) (0.14.2)
# Requirement already satisfied: pandas>=1.0.5 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from category_encoders) (0.5.6)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-5.3.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from yfinance) (2024.1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.4-py312-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.6.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 2.9 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (1.8.2)
# Requirement already satisfied: six>=1.9 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (8.5.0)
# Requirement already satisfied: packaging in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests->dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from requests->dash) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/dorukcanga/python3_12env/lib/python3.12/site-packages (from Werkzeug<3.1->dash) (2.1.5)
# Collecting zipp>=0.5 (from importlib-metadata->dash)
#   Downloading zipp-3.20.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading imbalanced_learn-0.12.3-py3-none-any.whl (258 kB)
# Downloading AutoFeatSelect-0.1.5-py3-none-any.whl (12 kB)
# Downloading dash-2.17.1-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
# Downloading yfinance-0.2.41-py2.py3-none-any.whl (73 kB)
# Downloading frozendict-2.4.4-py312-none-any.whl (16 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-5.3.0-cp312-cp312-macosx_10_9_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading Boruta-0.3-py3-none-any.whl (56 kB)
# Downloading importlib_metadata-8.2.0-py3-none-any.whl (25 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zipp-3.20.0-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.6-py3-none-any.whl size=138890 sha256=c954a27464d3ae711795b3a3e0b898ac9abe848fde66e0eee8497dd9f2048dca
#   Stored in directory: /Users/dorukcanga/Library/Caches/pip/wheels/a6/5e/0f/8319805c4115320e0d3e8fb5799b114a2e4c4a3d6c7e523b06
# Successfully built peewee
# Installing collected packages: peewee, multitasking, dash-table, dash-html-components, dash-core-components, zipp, retrying, lxml, html5lib, frozendict, importlib-metadata, yfinance, imbalanced-learn, dash, Boruta, category_encoders, autofeatselect
# Successfully installed Boruta-0.3 autofeatselect-0.1.5 category_encoders-2.6.3 dash-2.17.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 frozendict-2.4.4 html5lib-1.1 imbalanced-learn-0.12.3 importlib-metadata-8.2.0 lxml-5.3.0 multitasking-0.0.11 peewee-3.17.6 retrying-1.3.4 yfinance-0.2.41 zipp-3.20.0

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# absl-py                   2.1.0
# altair                    5.4.0
# annotated-types           0.7.0
# anyio                     4.4.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asgiref                   3.8.1
# asttokens                 2.4.1
# astunparse                1.6.3
# async-lru                 2.0.4
# attrs                     24.2.0
# AutoFeatSelect            0.1.5
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# blinker                   1.8.2
# Boruta                    0.3
# cachetools                5.4.0
# catboost                  1.2.5
# category-encoders         2.6.3
# certifi                   2024.7.4
# cffi                      1.17.0
# charset-normalizer        3.3.2
# click                     8.1.7
# comm                      0.2.2
# contourpy                 1.2.1
# cycler                    0.12.1
# dash                      2.17.1
# dash-core-components      2.0.0
# dash-html-components      2.0.0
# dash-table                5.0.0
# debugpy                   1.8.5
# decorator                 5.1.1
# defusedxml                0.7.1
# Django                    5.1
# docker                    7.1.0
# executing                 2.0.1
# fastapi                   0.112.0
# fastjsonschema            2.20.0
# filelock                  3.15.4
# Flask                     3.0.3
# flatbuffers               24.3.25
# fonttools                 4.53.1
# fqdn                      1.5.1
# frozendict                2.4.4
# fsspec                    2024.6.1
# gast                      0.6.0
# gensim                    4.3.3
# gitdb                     4.0.11
# GitPython                 3.1.43
# google-pasta              0.2.0
# graphviz                  0.20.3
# grpcio                    1.65.4
# h11                       0.14.0
# h5py                      3.11.0
# html5lib                  1.1
# httpcore                  1.0.5
# httpx                     0.27.0
# idna                      3.7
# imageio                   2.34.2
# imbalanced-learn          0.12.3
# importlib_metadata        8.2.0
# ipykernel                 6.29.5
# ipython                   8.26.0
# isoduration               20.11.0
# itsdangerous              2.2.0
# jedi                      0.19.1
# Jinja2                    3.1.4
# joblib                    1.4.2
# json5                     0.9.25
# jsonpointer               3.0.0
# jsonschema                4.23.0
# jsonschema-specifications 2023.12.1
# jupyter_client            8.6.2
# jupyter_core              5.7.2
# jupyter-events            0.10.0
# jupyter-lsp               2.2.5
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3
# jupyterlab                4.2.4
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# keras                     3.4.1
# kiwisolver                1.4.5
# lazy_loader               0.4
# libclang                  18.1.1
# lightgbm                  4.5.0
# lxml                      5.3.0
# Markdown                  3.6
# markdown-it-py            3.0.0
# MarkupSafe                2.1.5
# matplotlib                3.9.1.post1
# matplotlib-inline         0.1.7
# mdurl                     0.1.2
# mistune                   3.0.2
# ml-dtypes                 0.3.2
# mpmath                    1.3.0
# multitasking              0.0.11
# namex                     0.0.8
# narwhals                  1.3.0
# nbclient                  0.10.0
# nbconvert                 7.16.4
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.3
# nltk                      3.8.2
# notebook_shim             0.2.4
# numpy                     1.26.4
# opt-einsum                3.3.0
# optree                    0.12.1
# overrides                 7.7.0
# packaging                 24.1
# pandas                    2.2.2
# pandocfilters             1.5.1
# parso                     0.8.4
# patsy                     0.5.6
# peewee                    3.17.6
# pexpect                   4.9.0
# pillow                    10.4.0
# pip                       24.2
# platformdirs              4.2.2
# plotly                    5.23.0
# prometheus_client         0.20.0
# prompt_toolkit            3.0.47
# protobuf                  4.25.4
# psutil                    6.0.0
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pyarrow                   17.0.0
# pycparser                 2.22
# pydantic                  2.8.2
# pydantic_core             2.20.1
# pydeck                    0.9.1
# Pygments                  2.18.0
# pyparsing                 3.1.2
# python-dateutil           2.9.0.post0
# python-json-logger        2.0.7
# pytz                      2024.1
# PyYAML                    6.0.2
# pyzmq                     26.1.0
# referencing               0.35.1
# regex                     2024.7.24
# requests                  2.32.3
# retrying                  1.3.4
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rich                      13.7.1
# rpds-py                   0.20.0
# scikit-image              0.24.0
# scikit-learn              1.5.1
# scipy                     1.13.1
# seaborn                   0.13.2
# Send2Trash                1.8.3
# setuptools                72.1.0
# six                       1.16.0
# smart-open                7.0.4
# smmap                     5.0.1
# sniffio                   1.3.1
# soupsieve                 2.5
# sqlparse                  0.5.1
# stack-data                0.6.3
# starlette                 0.37.2
# statsmodels               0.14.2
# streamlit                 1.37.1
# sympy                     1.13.2
# tenacity                  8.5.0
# tensorboard               2.16.2
# tensorboard-data-server   0.7.2
# tensorflow                2.16.2
# termcolor                 2.4.0
# terminado                 0.18.1
# threadpoolctl             3.5.0
# tifffile                  2024.8.10
# tinycss2                  1.3.0
# toml                      0.10.2
# torch                     2.2.2
# torchvision               0.17.2
# tornado                   6.4.1
# tqdm                      4.66.5
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20240316
# typing_extensions         4.12.2
# tzdata                    2024.1
# uri-template              1.3.0
# urllib3                   2.2.2
# wcwidth                   0.2.13
# webcolors                 24.8.0
# webencodings              0.5.1
# websocket-client          1.8.0
# Werkzeug                  3.0.3
# wheel                     0.44.0
# wrapt                     1.16.0
# xgboost                   2.1.1
# yfinance                  0.2.41
# zipp                      3.20.0

# %%
import pandas as pd
import numpy as np
import bs4 as bs
import urllib.request
import json
import time

pd.set_option('display.max_columns', None)

# %%
def define_url(ticker, periods, financialgroup='XI_29'): #XI_29, UFRS, UFRS_K
    
    url = "https://www.isyatirim.com.tr/_layouts/15/IsYatirim.Website/Common/Data.aspx/"+\
           "MaliTablo?companyCode={}&exchange=TRY&financialGroup={}".format(ticker, financialgroup)+\
           "&year1={}&period1={}".format(periods[0][:4], str(int(periods[0][-1])*3))+\
           "&year2={}&period2={}".format(periods[1][:4], str(int(periods[1][-1])*3))+\
           "&year3={}&period3={}".format(periods[2][:4], str(int(periods[2][-1])*3))+\
           "&year4={}&period4={}".format(periods[3][:4], str(int(periods[3][-1])*3))#+\
           #"&_=1620763995205"
    
    return url

# %%
def get_data(url):
    
    s = urllib.request.urlopen(url).read()
    data = json.loads(s)
    
    return data

# %%
def get_financials(ticker, periods, financialgroup='XI_29'):
    
    
    url = define_url(ticker, periods, financialgroup)
    data = get_data(url)

    #check if all periods are missing.
    if data['value'] != list():
        itemCode_list, itemDescTr_list = [], []
        value_list1, value_list2, value_list3, value_list4 = [], [], [], []
        
        #check if some periods are missing. Only available periods will be added to dataframe.
        val_check1 = data['value'][0]['value1'] != None
        val_check2 = data['value'][0]['value2'] != None
        val_check3 = data['value'][0]['value3'] != None
        val_check4 = data['value'][0]['value4'] != None
        
        for elem in data['value']:
            itemCode_list.append(elem['itemCode'])
            itemDescTr_list.append(elem['itemDescTr'])
            if val_check1:
                value_list1.append(elem['value1'])
            if val_check2:
                value_list2.append(elem['value2'])
            if val_check3:
                value_list3.append(elem['value3'])
            if val_check4:
                value_list4.append(elem['value4'])

        temp_dict = {'itemCode' : itemCode_list, 'itemDescTr' : itemDescTr_list}

        if val_check1:
            temp_dict[periods[0]] = value_list1
        if val_check2:
            temp_dict[periods[1]] = value_list2
        if val_check3:
            temp_dict[periods[2]] = value_list3
        if val_check4:
            temp_dict[periods[3]] = value_list4

        temp_df = pd.DataFrame(temp_dict)

    else:
        temp_df = None

    return temp_df

# %%
def get_all_hist_financials(ticker, period_lists, financialgroup='XI_29', return_error_flag=True, verbose=True):
    
    check =True
    check_count = 0
    error_flag = False
    while check:
        try:
            #Get historical financial statements of the company.
            count = 0
            df = pd.DataFrame(columns = ['itemCode', 'itemDescTr'])
            for periods in period_lists:

                temp_df = get_financials(ticker, periods, financialgroup)

                if temp_df is not None:
                    df = df.merge(temp_df, on=['itemCode', 'itemDescTr'], how='outer')

                #Break request loop if none of current periods exists for the company.
                else:
                    break

                time.sleep(2)
                if verbose:
                    print(count, periods)
                count+=1
            check = False
        #Retry if connection error happens (Max 5 retries)
        except Exception:
            check_count +=1
            if check_count > 5:
                check = False
                error_flag = True
    
    if return_error_flag:
        return df, error_flag
    else:
        return df

# %%
isyatırım_df = pd.read_excel("/Users/dorukcanga/Downloads/tumhisse-3.xlsx")

# %%
ticker_list = list(isyatırım_df.sort_values('Hacim (TL)', ascending=False).Hisse.values)

ticker_list = [i.replace('                                     \u200b','').replace(' ','') for i in ticker_list]

# %%
period_lists = [
    ['2024/4', '2024/3', '2024/2', '2024/1'],
    ['2023/4', '2023/3', '2023/2', '2023/1'],
    ['2022/4', '2022/3', '2022/2', '2022/1'],
    ['2021/4', '2021/3', '2021/2', '2021/1'],
    ['2020/4', '2020/3', '2020/2', '2020/1'],
    ['2019/4', '2019/3', '2019/2', '2019/1'],
    ['2018/4', '2018/3', '2018/2', '2018/1'],
    ['2017/4', '2017/3', '2017/2', '2017/1'],
    ['2016/4', '2016/3', '2016/2', '2016/1'],
    ['2015/4', '2015/3', '2015/2', '2015/1'],
    ['2014/4', '2014/3', '2014/2', '2014/1'],
    ['2013/4', '2013/3', '2013/2', '2013/1'],
    ['2012/4', '2012/3', '2012/2', '2012/1'],
    ['2011/4', '2011/3', '2011/2', '2011/1'],
    ['2010/4', '2010/3', '2010/2', '2010/1'],
    ['2009/4', '2009/3', '2009/2', '2009/1'],
    ['2008/4', '2008/3', '2008/2', '2008/1']
]

# %%
period_lists2 = [
    #['2024/4', '2024/3', '2024/2', '2024/1'],
    ['2023/4', '2023/3', '2023/2', '2023/1'],
    ['2022/4', '2022/3', '2022/2', '2022/1'],
    ['2021/4', '2021/3', '2021/2', '2021/1'],
    ['2020/4', '2020/3', '2020/2', '2020/1'],
    ['2019/4', '2019/3', '2019/2', '2019/1'],
    ['2018/4', '2018/3', '2018/2', '2018/1'],
    ['2017/4', '2017/3', '2017/2', '2017/1'],
    ['2016/4', '2016/3', '2016/2', '2016/1'],
    ['2015/4', '2015/3', '2015/2', '2015/1'],
    ['2014/4', '2014/3', '2014/2', '2014/1'],
    ['2013/4', '2013/3', '2013/2', '2013/1'],
    ['2012/4', '2012/3', '2012/2', '2012/1'],
    ['2011/4', '2011/3', '2011/2', '2011/1'],
    ['2010/4', '2010/3', '2010/2', '2010/1'],
    ['2009/4', '2009/3', '2009/2', '2009/1'],
    ['2008/4', '2008/3', '2008/2', '2008/1']
]

# %%
ufrs_list = ['YKBNK', 'ISCTR', 'AKBNK', 'GARAN', 'ALTIN', 'VAKBN', 'HALKB', 'SKBNK',
    'TSKB', 'TURSG', 'ANSGR', 'KTLEV', 'AKGRT', 'ALBRK', 'ISFIN', 'VAKFN',
    'ITTFH', 'AGESA', 'RAYSG', 'ULUFA', 'ANHYT', 'DOCO', 'ICBCT', 'GLCVY',
    'CRDFA', 'SEKFK', 'IDEAS', 'GARFA', 'QNBFB', 'BRKVY', 'KLNMA', 'ISBTR',
    'LIDFA', 'QNBFL', 'ISATR', 'ISKUR'
            ]

# %%
error_list = []

# %%
save_path = "/Users/dorukcanga/Desktop/vid/data/bist/historical_financials/"

# %%
ticker_list2 = ['YKBNK', 'ISCTR', 'AKBNK', 'GARAN', 'ALTIN', 'VAKBN', 'HALKB', 'SKBNK',
    'TSKB', 'TURSG', 'ANSGR', 'KTLEV', 'AKGRT', 'ALBRK', 'ISFIN', 'VAKFN',
    'ITTFH', 'AGESA', 'RAYSG', 'ULUFA', 'ANHYT', 'DOCO', 'ICBCT', 'GLCVY',
    'CRDFA', 'SEKFK', 'IDEAS', 'GARFA', 'QNBFB', 'BRKVY', 'KLNMA', 'ISBTR',
    'LIDFA', 'QNBFL', 'ISATR', 'ISKUR'
            ]

# %%
# %%time

for ticker in ticker_list:
    
    financialgroup = 'UFRS_K' if ticker in ufrs_list else 'XI_29'
    
    df, error_flag = get_all_hist_financials(ticker, period_lists, financialgroup=financialgroup, return_error_flag=True, verbose=False)
    deneme_no = 1
    if len(df) == 0:
        df, error_flag = get_all_hist_financials(ticker, period_lists2, financialgroup=financialgroup, return_error_flag=True, verbose=False)
        deneme_no = 2
    
    if error_flag:
        error_list.append(ticker)
        print(ticker, "-> Error!")
    else:
        df.to_csv(save_path+ticker+'.csv', index=False)
        print(ticker, "-> Saved! Deneme:", deneme_no)
        
    time.sleep(10)
# Out:
# THYAO -> Saved! Deneme: 1
# TUPRS -> Saved! Deneme: 1
# YKBNK -> Saved! Deneme: 2
# ISCTR -> Saved! Deneme: 2
# KCHOL -> Saved! Deneme: 1
# AKBNK -> Saved! Deneme: 2
# BORLS -> Saved! Deneme: 1
# EREGL -> Saved! Deneme: 1
# BRSAN -> Saved! Deneme: 1
# PETKM -> Saved! Deneme: 1
# BIMAS -> Saved! Deneme: 1
# GUBRF -> Saved! Deneme: 1
# GARAN -> Saved! Deneme: 2
# ODAS -> Saved! Deneme: 1
# KONTR -> Saved! Deneme: 1
# ASELS -> Saved! Deneme: 1
# ASTOR -> Saved! Deneme: 1
# SISE -> Saved! Deneme: 1
# MIATK -> Saved! Deneme: 1
# FROTO -> Saved! Deneme: 1
# PGSUS -> Saved! Deneme: 1
# TOASO -> Saved! Deneme: 1
# SAHOL -> Saved! Deneme: 1
# SASA -> Saved! Deneme: 1
# KOZAL -> Saved! Deneme: 2
# EKGYO -> Saved! Deneme: 1
# TCELL -> Saved! Deneme: 1
# ALTIN -> Saved! Deneme: 2
# ZOREN -> Saved! Deneme: 1
# VAKBN -> Saved! Deneme: 2
# FENER -> Saved! Deneme: 2
# KRDMD -> Saved! Deneme: 1
# EUPWR -> Saved! Deneme: 1
# INGRM -> Saved! Deneme: 1
# ULKER -> Saved! Deneme: 1
# HEKTS -> Saved! Deneme: 1
# GESAN -> Saved! Deneme: 1
# YEOTK -> Saved! Deneme: 1
# OYAKC -> Saved! Deneme: 1
# ALARK -> Saved! Deneme: 1
# CIMSA -> Saved! Deneme: 1
# ENJSA -> Saved! Deneme: 1
# ALFAS -> Saved! Deneme: 1
# ENKAI -> Saved! Deneme: 1
# TTKOM -> Saved! Deneme: 1
# HALKB -> Saved! Deneme: 2
# TAVHL -> Saved! Deneme: 1
# ARCLK -> Saved! Deneme: 1
# DOAS -> Saved! Deneme: 1
# CWENE -> Saved! Deneme: 1
# KOZAA -> Saved! Deneme: 2
# SMRTG -> Saved! Deneme: 1
# GSRAY -> Saved! Deneme: 2
# DOHOL -> Saved! Deneme: 1
# SKBNK -> Saved! Deneme: 2
# MAGEN -> Saved! Deneme: 1
# MGROS -> Saved! Deneme: 1
# CANTE -> Saved! Deneme: 1
# AFYON -> Saved! Deneme: 1
# BERA -> Saved! Deneme: 1
# ECZYT -> Saved! Deneme: 1
# SOKM -> Saved! Deneme: 1
# EGEEN -> Saved! Deneme: 1
# KONYA -> Saved! Deneme: 1
# ENERY -> Saved! Deneme: 1
# BIOEN -> Saved! Deneme: 1
# BRYAT -> Saved! Deneme: 1
# TKFEN -> Saved! Deneme: 1
# TTRAK -> Saved! Deneme: 1
# ISMEN -> Saved! Deneme: 1
# IZENR -> Saved! Deneme: 1
# TSKB -> Saved! Deneme: 2
# ERBOS -> Saved! Deneme: 1
# ECILC -> Saved! Deneme: 1
# IPEKE -> Saved! Deneme: 2
# SDTTR -> Saved! Deneme: 1
# TURSG -> Saved! Deneme: 2
# BUCIM -> Saved! Deneme: 1
# ANSGR -> Saved! Deneme: 2
# AEFES -> Saved! Deneme: 1
# KLSER -> Saved! Deneme: 1
# AYGAZ -> Saved! Deneme: 1
# TKNSA -> Saved! Deneme: 1
# BFREN -> Saved! Deneme: 2
# BOBET -> Saved! Deneme: 1
# AKFYE -> Saved! Deneme: 1
# MHRGY -> Saved! Deneme: 1
# BRLSM -> Saved! Deneme: 1
# VESTL -> Saved! Deneme: 1
# CVKMD -> Saved! Deneme: 1
# AKCNS -> Saved! Deneme: 1
# ISGYO -> Saved! Deneme: 1
# KTLEV -> Saved! Deneme: 2
# INVEO -> Saved! Deneme: 1
# FMIZP -> Saved! Deneme: 1
# KATMR -> Saved! Deneme: 1
# AKSEN -> Saved! Deneme: 1
# VESBE -> Saved! Deneme: 1
# OTKAR -> Saved! Deneme: 1
# TSPOR -> Saved! Deneme: 2
# KCAER -> Saved! Deneme: 1
# TATEN -> Saved! Deneme: 1
# ELITE -> Saved! Deneme: 1
# BVSAN -> Saved! Deneme: 1
# AHGAZ -> Saved! Deneme: 1
# BTCIM -> Saved! Deneme: 2
# TMSN -> Saved! Deneme: 1
# KAYSE -> Saved! Deneme: 2
# BIENY -> Saved! Deneme: 1
# NUHCM -> Saved! Deneme: 1
# A1CAP -> Saved! Deneme: 1
# ADESE -> Saved! Deneme: 1
# MAVI -> Saved! Deneme: 1
# AKGRT -> Saved! Deneme: 2
# ASUZU -> Saved! Deneme: 1
# ASGYO -> Saved! Deneme: 1
# DYOBY -> Saved! Deneme: 1
# PEGYO -> Saved! Deneme: 2
# CCOLA -> Saved! Deneme: 1
# HATSN -> Saved! Deneme: 1
# EBEBK -> Saved! Deneme: 1
# ALBRK -> Saved! Deneme: 2
# IEYHO -> Saved! Deneme: 1
# ADGYO -> Saved! Deneme: 1
# KLRHO -> Saved! Deneme: 2
# ERCB -> Saved! Deneme: 1
# MPARK -> Saved! Deneme: 1
# GWIND -> Saved! Deneme: 1
# GLYHO -> Saved! Deneme: 1
# KLGYO -> Saved! Deneme: 1
# PEKGY -> Saved! Deneme: 1
# CLEBI -> Saved! Deneme: 1
# EUREN -> Saved! Deneme: 1
# KARSN -> Saved! Deneme: 1
# REEDR -> Saved! Deneme: 1
# DOFER -> Saved! Deneme: 1
# GIPTA -> Saved! Deneme: 1
# PASEU -> Saved! Deneme: 1
# AKSA -> Saved! Deneme: 1
# GSDHO -> Saved! Deneme: 1
# CMBTN -> Saved! Deneme: 1
# MAALT -> Saved! Deneme: 1
# AGHOL -> Saved! Deneme: 1
# TRGYO -> Saved! Deneme: 1
# YYAPI -> Saved! Deneme: 1
# GOLTS -> Saved! Deneme: 1
# ISDMR -> Saved! Deneme: 1
# PSGYO -> Saved! Deneme: 1
# KLKIM -> Saved! Deneme: 1
# VKGYO -> Saved! Deneme: 1
# KMPUR -> Saved! Deneme: 1
# YYLGD -> Saved! Deneme: 1
# AGYO -> Saved! Deneme: 1
# TUKAS -> Saved! Deneme: 1
# SAYAS -> Saved! Deneme: 1
# GOKNR -> Saved! Deneme: 1
# KORDS -> Saved! Deneme: 1
# LIDER -> Saved! Deneme: 1
# OFSYM -> Saved! Deneme: 1
# GENIL -> Saved! Deneme: 1
# CEMTS -> Saved! Deneme: 1
# ISFIN -> Saved! Deneme: 2
# LOGO -> Saved! Deneme: 1
# GOZDE -> Saved! Deneme: 1
# SNGYO -> Saved! Deneme: 1
# RYGYO -> Saved! Deneme: 1
# ESEN -> Saved! Deneme: 1
# IHLAS -> Saved! Deneme: 1
# YESIL -> Saved! Deneme: 1
# QUAGR -> Saved! Deneme: 1
# FORTE -> Saved! Deneme: 1
# MRSHL -> Saved! Deneme: 1
# INVES -> Saved! Deneme: 1
# KZGYO -> Saved! Deneme: 1
# INDES -> Saved! Deneme: 1
# AVHOL -> Saved! Deneme: 1
# ACSEL -> Saved! Deneme: 1
# KUYAS -> Saved! Deneme: 1
# ORGE -> Saved! Deneme: 1
# VAKFN -> Saved! Deneme: 2
# POLHO -> Saved! Deneme: 1
# VBTYZ -> Saved! Deneme: 1
# TURGG -> Saved! Deneme: 1
# HUNER -> Saved! Deneme: 1
# YAPRK -> Saved! Deneme: 1
# EKSUN -> Saved! Deneme: 1
# ALCTL -> Saved! Deneme: 1
# KRDMA -> Saved! Deneme: 1
# ONCSM -> Saved! Deneme: 1
# CRFSA -> Saved! Deneme: 1
# ULUSE -> Saved! Deneme: 2
# KZBGY -> Saved! Deneme: 1
# TARKM -> Saved! Deneme: 1
# FZLGY -> Saved! Deneme: 1
# INTEM -> Saved! Deneme: 1
# TABGD -> Saved! Deneme: 1
# BAGFS -> Saved! Deneme: 1
# MEKAG -> Saved! Deneme: 1
# ATAKP -> Saved! Deneme: 1
# KOPOL -> Saved! Deneme: 1
# IHLGM -> Saved! Deneme: 1
# OZKGY -> Saved! Deneme: 1
# SNICA -> Saved! Deneme: 1
# IMASM -> Saved! Deneme: 1
# IZMDC -> Saved! Deneme: 1
# GEDIK -> Saved! Deneme: 1
# MOBTL -> Saved! Deneme: 1
# UNLU -> Saved! Deneme: 1
# ARZUM -> Saved! Deneme: 1
# GRSEL -> Saved! Deneme: 1
# YGYO -> Saved! Deneme: 1
# CEOEM -> Saved! Deneme: 1
# PENTA -> Saved! Deneme: 1
# GRTRK -> Saved! Deneme: 1
# BSOKE -> Saved! Deneme: 1
# FORMT -> Saved! Deneme: 1
# JANTS -> Saved! Deneme: 1
# PRZMA -> Saved! Deneme: 1
# ALGYO -> Saved! Deneme: 1
# AKFGY -> Saved! Deneme: 1
# RTALB -> Saved! Deneme: 1
# ALCAR -> Saved! Deneme: 1
# SRVGY -> Saved! Deneme: 1
# SEGYO -> Saved! Deneme: 1
# PARSN -> Saved! Deneme: 1
# YUNSA -> Saved! Deneme: 1
# AYDEM -> Saved! Deneme: 1
# NTHOL -> Saved! Deneme: 1
# OSMEN -> Saved! Deneme: 1
# NATEN -> Saved! Deneme: 1
# DAPGM -> Saved! Deneme: 1
# IHAAS -> Saved! Deneme: 1
# KERVT -> Saved! Deneme: 1
# TRILC -> Saved! Deneme: 1
# NIBAS -> Saved! Deneme: 1
# VERUS -> Saved! Deneme: 1
# HKTM -> Saved! Deneme: 1
# ITTFH -> Saved! Deneme: 2
# CEMAS -> Saved! Deneme: 1
# GLRYH -> Saved! Deneme: 1
# MEGAP -> Saved! Deneme: 1
# NTGAZ -> Saved! Deneme: 1
# AVOD -> Saved! Deneme: 1
# AGESA -> Saved! Deneme: 2
# EGGUB -> Saved! Deneme: 1
# EGPRO -> Saved! Deneme: 1
# OBASE -> Saved! Deneme: 1
# FONET -> Saved! Deneme: 1
# SELVA -> Saved! Deneme: 1
# SOKE -> Saved! Deneme: 1
# ALMAD -> Saved! Deneme: 1
# HLGYO -> Saved! Deneme: 1
# PKENT -> Saved! Deneme: 1
# ISSEN -> Saved! Deneme: 1
# SELEC -> Saved! Deneme: 1
# KARTN -> Saved! Deneme: 2
# INFO -> Saved! Deneme: 1
# ARDYZ -> Saved! Deneme: 1
# DMRGD -> Saved! Deneme: 1
# KAREL -> Saved! Deneme: 1
# MACKO -> Saved! Deneme: 1
# BMSTL -> Saved! Deneme: 1
# RAYSG -> Saved! Deneme: 2
# SMART -> Saved! Deneme: 1
# EUHOL -> Saved! Deneme: 2
# DOKTA -> Saved! Deneme: 1
# TRCAS -> Saved! Deneme: 1
# ULUUN -> Saved! Deneme: 1
# ADEL -> Saved! Deneme: 1
# ZEDUR -> Saved! Deneme: 1
# BARMA -> Saved! Deneme: 1
# PCILT -> Saved! Deneme: 1
# DENGE -> Saved! Deneme: 1
# ULUFA -> Saved! Deneme: 2
# PAPIL -> Saved! Deneme: 1
# TNZTP -> Saved! Deneme: 1
# EMKEL -> Saved! Deneme: 1
# NUGYO -> Saved! Deneme: 1
# IHGZT -> Saved! Deneme: 1
# TEZOL -> Saved! Deneme: 1
# BIZIM -> Saved! Deneme: 1
# HDFGS -> Saved! Deneme: 1
# GZNMI -> Saved! Deneme: 1
# YKSLN -> Saved! Deneme: 1
# USAK -> Saved! Deneme: 1
# IZFAS -> Saved! Deneme: 1
# DEVA -> Saved! Deneme: 1
# CONSE -> Saved! Deneme: 1
# MARKA -> Saved! Deneme: 1
# PNLSN -> Saved! Deneme: 1
# MNDRS -> Saved! Deneme: 1
# KONKA -> Saved! Deneme: 1
# BYDNR -> Saved! Deneme: 1
# MRGYO -> Saved! Deneme: 2
# MARTI -> Saved! Deneme: 2
# PAMEL -> Saved! Deneme: 1
# COSMO -> Saved! Deneme: 1
# BJKAS -> Saved! Deneme: 2
# ALKIM -> Saved! Deneme: 1
# SUWEN -> Saved! Deneme: 1
# KRONT -> Saved! Deneme: 1
# TATGD -> Saved! Deneme: 1
# GOODY -> Saved! Deneme: 1
# YATAS -> Saved! Deneme: 1
# KRDMB -> Saved! Deneme: 1
# SANFM -> Saved! Deneme: 1
# FRIGO -> Saved! Deneme: 1
# ANHYT -> Saved! Deneme: 2
# BASGZ -> Saved! Deneme: 1
# OSTIM -> Saved! Deneme: 1
# ENSRI -> Saved! Deneme: 1
# TUCLK -> Saved! Deneme: 1
# AKENR -> Saved! Deneme: 1
# METRO -> Saved! Deneme: 1
# VAKKO -> Saved! Deneme: 1
# KLMSN -> Saved! Deneme: 1
# IHEVA -> Saved! Deneme: 1
# KLSYN -> Saved! Deneme: 1
# MEDTR -> Saved! Deneme: 1
# ANELE -> Saved! Deneme: 1
# KIMMR -> Saved! Deneme: 1
# DOCO -> Saved! Deneme: 2
# ICBCT -> Saved! Deneme: 2
# KTSKR -> Saved! Deneme: 1
# KRSTL -> Saved! Deneme: 1
# ANGEN -> Saved! Deneme: 1
# PRKME -> Saved! Deneme: 1
# OYLUM -> Saved! Deneme: 1
# KRVGD -> Saved! Deneme: 1
# PRDGS -> Saved! Deneme: 1
# BRISA -> Saved! Deneme: 1
# PLTUR -> Saved! Deneme: 1
# KGYO -> Saved! Deneme: 1
# BURCE -> Saved! Deneme: 1
# AYEN -> Saved! Deneme: 1
# AKMGY -> Saved! Deneme: 1
# ALKA -> Saved! Deneme: 1
# BANVT -> Saved! Deneme: 1
# OZGYO -> Saved! Deneme: 1
# AZTEK -> Saved! Deneme: 1
# FLAP -> Saved! Deneme: 1
# VERTU -> Saved! Deneme: 1
# HTTBT -> Saved! Deneme: 1
# MAKIM -> Saved! Deneme: 1
# OYYAT -> Saved! Deneme: 1
# PENGD -> Saved! Deneme: 1
# LKMNH -> Saved! Deneme: 1
# AVTUR -> Saved! Deneme: 1
# RALYH -> Saved! Deneme: 1
# ESCAR -> Saved! Deneme: 1
# DZGYO -> Saved! Deneme: 1
# MERKO -> Saved! Deneme: 2
# FADE -> Saved! Deneme: 1
# TERA -> Saved! Deneme: 1
# ISGSY -> Saved! Deneme: 1
# DGNMO -> Saved! Deneme: 1
# RNPOL -> Saved! Deneme: 1
# EPLAS -> Saved! Deneme: 1
# BEYAZ -> Saved! Deneme: 1
# KAPLM -> Saved! Deneme: 1
# ESCOM -> Saved! Deneme: 1
# KUTPO -> Saved! Deneme: 1
# EDIP -> Saved! Deneme: 1
# ZRGYO -> Saved! Deneme: 1
# ARSAN -> Saved! Deneme: 1
# RUBNS -> Saved! Deneme: 1
# GLCVY -> Saved! Deneme: 2
# MAKTK -> Saved! Deneme: 1
# GEREL -> Saved! Deneme: 1
# BIGCH -> Saved! Deneme: 1
# DARDL -> Saved! Deneme: 1
# AKSGY -> Saved! Deneme: 1
# PRKAB -> Saved! Deneme: 1
# TMPOL -> Saved! Deneme: 1
# BNTAS -> Saved! Deneme: 1
# ATATP -> Saved! Deneme: 1
# GMTAS -> Saved! Deneme: 1
# MANAS -> Saved! Deneme: 1
# NETAS -> Saved! Deneme: 1
# HURGZ -> Saved! Deneme: 1
# ORCAY -> Saved! Deneme: 1
# SUNTK -> Saved! Deneme: 1
# HUBVC -> Saved! Deneme: 1
# SARKY -> Saved! Deneme: 1
# KARYE -> Saved! Deneme: 1
# CRDFA -> Saved! Deneme: 2
# DESA -> Saved! Deneme: 1
# DGGYO -> Saved! Deneme: 1
# KRGYO -> Saved! Deneme: 1
# KENT -> Saved! Deneme: 1
# EYGYO -> Saved! Deneme: 1
# MIPAZ -> Saved! Deneme: 1
# ISKPL -> Saved! Deneme: 1
# SEKFK -> Saved! Deneme: 2
# TGSAS -> Saved! Deneme: 1
# SEYKM -> Saved! Deneme: 1
# ETILR -> Saved! Deneme: 1
# BMSCH -> Saved! Deneme: 1
# EGEPO -> Saved! Deneme: 1
# CMENT -> Saved! Deneme: 1
# CASA -> Saved! Deneme: 1
# BLCYT -> Saved! Deneme: 1
# ETYAT -> Saved! Deneme: 1
# CELHA -> Saved! Deneme: 1
# DGATE -> Saved! Deneme: 1
# TLMAN -> Saved! Deneme: 1
# DERHL -> Saved! Deneme: 1
# TEKTU -> Saved! Deneme: 1
# OZSUB -> Saved! Deneme: 1
# ARASE -> Saved! Deneme: 1
# AKSUE -> Saved! Deneme: 1
# RYSAS -> Saved! Deneme: 1
# POLTK -> Saved! Deneme: 1
# IDEAS -> Saved! Deneme: 2
# AYCES -> Saved! Deneme: 1
# SAFKR -> Saved! Deneme: 1
# PINSU -> Saved! Deneme: 1
# DNISI -> Saved! Deneme: 1
# MERCN -> Saved! Deneme: 1
# AVGYO -> Saved! Deneme: 1
# KRPLS -> Saved! Deneme: 1
# MNDTR -> Saved! Deneme: 2
# DURDO -> Saved! Deneme: 1
# EDATA -> Saved! Deneme: 1
# VANGD -> Saved! Deneme: 1
# GENTS -> Saved! Deneme: 1
# SANKO -> Saved! Deneme: 1
# LINK -> Saved! Deneme: 1
# DOBUR -> Saved! Deneme: 1
# ISYAT -> Saved! Deneme: 1
# PNSUT -> Saved! Deneme: 1
# VKFYO -> Saved! Deneme: 1
# MERIT -> Saved! Deneme: 1
# TSGYO -> Saved! Deneme: 1
# TUREX -> Saved! Deneme: 1
# ORMA -> Saved! Deneme: 2
# MZHLD -> Saved! Deneme: 1
# ISBIR -> Saved! Deneme: 2
# DITAS -> Saved! Deneme: 1
# HATEK -> Saved! Deneme: 1
# EGSER -> Saved! Deneme: 1
# GARFA -> Saved! Deneme: 2
# BOSSA -> Saved! Deneme: 1
# CUSAN -> Saved! Deneme: 1
# KFEIN -> Saved! Deneme: 1
# GSDDE -> Saved! Deneme: 1
# METUR -> Saved! Deneme: 1
# BAKAB -> Saved! Deneme: 1
# ULAS -> Saved! Deneme: 1
# KRTEK -> Saved! Deneme: 1
# PAGYO -> Saved! Deneme: 1
# ARENA -> Saved! Deneme: 1
# SAMAT -> Saved! Deneme: 1
# QNBFB -> Saved! Deneme: 2
# IDGYO -> Saved! Deneme: 1
# MTRKS -> Saved! Deneme: 1
# ATEKS -> Saved! Deneme: 1
# YBTAS -> Saved! Deneme: 2
# BRKVY -> Saved! Deneme: 2
# UZERB -> Saved! Deneme: 2
# DMSAS -> Saved! Deneme: 1
# KLNMA -> Saved! Deneme: 2
# MSGYO -> Saved! Deneme: 1
# GLBMD -> Saved! Deneme: 1
# OZRDN -> Saved! Deneme: 2
# EUKYO -> Saved! Deneme: 1
# LUKSK -> Saved! Deneme: 1
# PETUN -> Saved! Deneme: 1
# EKIZ -> Saved! Deneme: 1
# ISBTR -> Saved! Deneme: 2
# TDGYO -> Saved! Deneme: 1
# GEDZA -> Saved! Deneme: 1
# IHYAY -> Saved! Deneme: 1
# LIDFA -> Saved! Deneme: 2
# HEDEF -> Saved! Deneme: 1
# KNFRT -> Saved! Deneme: 1
# KSTUR -> Saved! Deneme: 2
# TETMT -> Saved! Deneme: 1
# DOGUB -> Saved! Deneme: 1
# QNBFL -> Saved! Deneme: 2
# SKTAS -> Saved! Deneme: 1
# AYES -> Saved! Deneme: 2
# BRKSN -> Saved! Deneme: 1
# VKING -> Saved! Deneme: 1
# TBORG -> Saved! Deneme: 1
# DAGI -> Saved! Deneme: 1
# PKART -> Saved! Deneme: 1
# UFUK -> Saved! Deneme: 1
# SILVR -> Saved! Deneme: 1
# BASCM -> Saved! Deneme: 2
# SODSN -> Saved! Deneme: 2
# MTRYO -> Saved! Deneme: 1
# PSDTC -> Saved! Deneme: 1
# IZINV -> Saved! Deneme: 2
# MEPET -> Saved! Deneme: 1
# KRONT -> Saved! Deneme: 1
# OYAYO -> Saved! Deneme: 1
# YGGYO -> Saved! Deneme: 1
# SEKUR -> Saved! Deneme: 1
# ERSU -> Saved! Deneme: 1
# YAYLA -> Saved! Deneme: 1
# ATLAS -> Saved! Deneme: 1
# BALAT -> Saved! Deneme: 2
# KUVVA -> Saved! Deneme: 1
# EMNIS -> Saved! Deneme: 1
# BURVA -> Saved! Deneme: 1
# AKYHO -> Saved! Deneme: 1
# UMPAS -> Saved! Deneme: 2
# GRNYO -> Saved! Deneme: 1
# SONME -> Saved! Deneme: 1
# SNKRN -> Saved! Deneme: 1
# SUMAS -> Saved! Deneme: 2
# ICUGS -> Saved! Deneme: 1
# RODRG -> Saved! Deneme: 1
# EUYO -> Saved! Deneme: 1
# ATAGY -> Saved! Deneme: 1
# DERIM -> Saved! Deneme: 1
# DAGHL -> Saved! Deneme: 1
# SANEL -> Saved! Deneme: 2
# BAYRK -> Saved! Deneme: 1
# SELGD -> Saved! Deneme: 1
# BRKO -> Saved! Deneme: 1
# YONGA -> Saved! Deneme: 2
# KERVN -> Saved! Deneme: 1
# BRMEN -> Saved! Deneme: 1
# SNPAM -> Saved! Deneme: 1
# OTTO -> Saved! Deneme: 1
# DESPC -> Saved! Deneme: 1
# MMCAS -> Saved! Deneme: 2
# DIRIT -> Saved! Deneme: 1
# DITAS -> Saved! Deneme: 1
# ATSYH -> Saved! Deneme: 1
# ISATR -> Saved! Deneme: 2
# ROYAL -> Saved! Deneme: 2
# ISKUR -> Saved! Deneme: 2
# CPU times: user 1min 53s, sys: 11.6 s, total: 2min 5s
# Wall time: 6h 5min 22s

# %%
# %%time

for ticker in ticker_list2:
    
    financialgroup = 'UFRS_K' if ticker in ufrs_list else 'XI_29'
    
    df, error_flag = get_all_hist_financials(ticker, period_lists, financialgroup=financialgroup, return_error_flag=True, verbose=False)
    deneme_no = 1
    if len(df) == 0:
        df, error_flag = get_all_hist_financials(ticker, period_lists2, financialgroup=financialgroup, return_error_flag=True, verbose=False)
        deneme_no = 2
    
    if error_flag:
        error_list.append(ticker)
        print(ticker, "-> Error!")
    else:
        df.to_csv(save_path+ticker+'.csv', index=False)
        print(ticker, "-> Saved! Deneme:", deneme_no)
        
    time.sleep(10)
# Out:
# YKBNK -> Saved! Deneme: 1
# ISCTR -> Saved! Deneme: 1
# AKBNK -> Saved! Deneme: 1
# GARAN -> Saved! Deneme: 1
# ALTIN -> Saved! Deneme: 2
# VAKBN -> Saved! Deneme: 1
# HALKB -> Saved! Deneme: 1
# SKBNK -> Saved! Deneme: 1
# TSKB -> Saved! Deneme: 1
# TURSG -> Saved! Deneme: 1
# ANSGR -> Saved! Deneme: 1
# KTLEV -> Saved! Deneme: 2
# AKGRT -> Saved! Deneme: 1
# ALBRK -> Saved! Deneme: 1
# ISFIN -> Saved! Deneme: 2
# VAKFN -> Saved! Deneme: 2
# ITTFH -> Saved! Deneme: 2
# AGESA -> Saved! Deneme: 1
# RAYSG -> Saved! Deneme: 2
# ULUFA -> Saved! Deneme: 2
# ANHYT -> Saved! Deneme: 1
# DOCO -> Saved! Deneme: 2
# ICBCT -> Saved! Deneme: 1
# GLCVY -> Saved! Deneme: 2
# CRDFA -> Saved! Deneme: 2
# SEKFK -> Saved! Deneme: 2
# IDEAS -> Saved! Deneme: 2
# GARFA -> Saved! Deneme: 2
# QNBFB -> Saved! Deneme: 1
# BRKVY -> Saved! Deneme: 2
# KLNMA -> Saved! Deneme: 1
# ISBTR -> Saved! Deneme: 1
# LIDFA -> Saved! Deneme: 2
# QNBFL -> Saved! Deneme: 2
# ISATR -> Saved! Deneme: 1
# ISKUR -> Saved! Deneme: 2
# CPU times: user 5.27 s, sys: 688 ms, total: 5.96 s
# Wall time: 17min 24s

# %%
error_list
# Out:
# []
